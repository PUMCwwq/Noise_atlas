# %% [markdown]
# ### 数据规整 → 来源于 FLU_fastq_download.ipyb

# %%
import monod
from monod import *
from monod.preprocess import *
from monod.extract_data import *
from monod.cme_toolbox import CMEModel
from monod import inference, mminference
from monod.analysis import *
from monod import preprocess, extract_data, cme_toolbox, inference, analysis

# %%
# 把data2生成的2个文件夹统一cp到data路径下 -- 为方便一起处理
# !cp -r /data2/wuwq/noise/monod_FLU/SRR11680207_OUTDIR/SRR11680207 \
       /data/wuwq/noise/Monod_FLU/ori_loom/
# !cp -r /data2/wuwq/noise/monod_FLU/SRR11680209_OUTDIR \
       /data/wuwq/noise/Monod_FLU/ori_loom/

# %%
# 把生成的loom文件复制到/data/wuwq/noise/Monod_FLU/ori_loom/
# !cp /data2/wuwq/noise/monod_FLU/SRR11680207_OUTDIR/SRR11680207/counts_filtered/adata.loom \
    /data/wuwq/noise/Monod_FLU/ori_loom/covid1_s1.loom
# !cp /data2/wuwq/noise/monod_FLU/SRR11680209_OUTDIR/counts_filtered/adata.loom \
    /data/wuwq/noise/Monod_FLU/ori_loom/flu1_s3.loom

# !cp /data/wuwq/noise/Monod_FLU/ori_loom/SRR11680208_OUTDIR/counts_filtered/adata.loom \
    /data/wuwq/noise/Monod_FLU/ori_loom/covid2_s2.loom
# !cp /data/wuwq/noise/Monod_FLU/ori_loom/SRR11680210_OUTDIR/counts_filtered/adata.loom \
    /data/wuwq/noise/Monod_FLU/ori_loom/flu2_s4.loom

# !cp /data/wuwq/noise/Monod_FLU/ori_loom/SRR11680211_OUTDIR/counts_filtered/adata.loom \
    /data/wuwq/noise/Monod_FLU/ori_loom/nor1_s5.loom
# !cp /data/wuwq/noise/Monod_FLU/ori_loom/SRR11680212_OUTDIR/counts_filtered/adata.loom \
    /data/wuwq/noise/Monod_FLU/ori_loom/flu3_s6.loom

# !cp /data/wuwq/noise/Monod_FLU/ori_loom/SRR11680213_OUTDIR/counts_filtered/adata.loom \
    /data/wuwq/noise/Monod_FLU/ori_loom/flu4_s7.loom
# !cp /data/wuwq/noise/Monod_FLU/ori_loom/SRR11680214_OUTDIR/counts_filtered/adata.loom \
    /data/wuwq/noise/Monod_FLU/ori_loom/flu5_s8.loom

# !cp /data/wuwq/noise/Monod_FLU/ori_loom/SRR11680215_OUTDIR/counts_filtered/adata.loom \
    /data/wuwq/noise/Monod_FLU/ori_loom/covid3_s9.loom
# !cp /data/wuwq/noise/Monod_FLU/ori_loom/SRR11680216_OUTDIR/counts_filtered/adata.loom \
    /data/wuwq/noise/Monod_FLU/ori_loom/covid4_s10.loom

# !cp /data/wuwq/noise/Monod_FLU/ori_loom/SRR11680217_OUTDIR/counts_filtered/adata.loom \
    /data/wuwq/noise/Monod_FLU/ori_loom/covid5_s11.loom
# !cp /data/wuwq/noise/Monod_FLU/ori_loom/SRR11680218_OUTDIR/counts_filtered/adata.loom \
    /data/wuwq/noise/Monod_FLU/ori_loom/covid6_s12.loom

# !cp /data/wuwq/noise/Monod_FLU/ori_loom/SRR11680219_OUTDIR/counts_filtered/adata.loom \
    /data/wuwq/noise/Monod_FLU/ori_loom/nor2_s13.loom
# !cp /data/wuwq/noise/Monod_FLU/ori_loom/SRR11680220_OUTDIR/counts_filtered/adata.loom \
    /data/wuwq/noise/Monod_FLU/ori_loom/nor3_s14.loom

# !cp /data/wuwq/noise/Monod_FLU/ori_loom/SRR11680221_OUTDIR/counts_filtered/adata.loom \
    /data/wuwq/noise/Monod_FLU/ori_loom/covid7_s15.loom
# !cp /data/wuwq/noise/Monod_FLU/ori_loom/SRR11680222_OUTDIR/counts_filtered/adata.loom \
    /data/wuwq/noise/Monod_FLU/ori_loom/covid8_s16.loom

# !cp /data/wuwq/noise/Monod_FLU/ori_loom/SRR11680223_OUTDIR/counts_filtered/adata.loom \
    /data/wuwq/noise/Monod_FLU/ori_loom/covid9_s17.loom
# !cp /data/wuwq/noise/Monod_FLU/ori_loom/SRR11680224_OUTDIR/counts_filtered/adata.loom \
    /data/wuwq/noise/Monod_FLU/ori_loom/covid10_s18.loom

# !cp /data/wuwq/noise/Monod_FLU/ori_loom/SRR11680225_OUTDIR/counts_filtered/adata.loom \
    /data/wuwq/noise/Monod_FLU/ori_loom/nor4_s19.loom
# !cp /data/wuwq/noise/Monod_FLU/ori_loom/SRR11680226_OUTDIR/counts_filtered/adata.loom \
    /data/wuwq/noise/Monod_FLU/ori_loom/covid11_s20.loom
